# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\riiti\appdata\local\programs\python\python310\lib\site-packages (2.10.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\riiti\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (3.7.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\riiti\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.0.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\riiti\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (0.27.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\riiti\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\riiti\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\riiti\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (3.19.5)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\riiti\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\riiti\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.0.7)
# Requirement already satisfied: keras<2.11,>=2.10.0 in c:\users\riiti\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\riiti\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.48.1)
# Requirement already satisfied: packaging in c:\users\riiti\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (21.3)
# Requirement already satisfied: setuptools in c:\users\riiti\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (63.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\riiti\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\riiti\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.23.3)
# Requirement already satisfied: six>=1.12.0 in c:\users\riiti\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\riiti\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.2.0)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in c:\users\riiti\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in c:\users\riiti\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\riiti\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\riiti\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (4.3.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\riiti\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\riiti\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (14.0.6)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\riiti\appdata\local\programs\python\python310\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\riiti\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.28.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\riiti\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\riiti\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.11.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\riiti\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\riiti\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\riiti\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.2.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\riiti\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (3.4.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\riiti\appdata\local\programs\python\python310\lib\site-packages (from packaging->tensorflow) (3.0.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\riiti\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (5.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\riiti\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\riiti\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\riiti\appdata\local\programs\python\python310\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\riiti\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\riiti\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (1.26.12)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\riiti\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\riiti\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2022.9.14)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\riiti\appdata\local\programs\python\python310\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.11,>=2.10->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\riiti\appdata\local\programs\python\python310\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\riiti\appdata\local\programs\python\python310\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (3.2.1)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\riiti\appdata\local\programs\python\python310\lib\site-packages (3.7)
# Requirement already satisfied: joblib in c:\users\riiti\appdata\local\programs\python\python310\lib\site-packages (from nltk) (1.1.0)
# Requirement already satisfied: click in c:\users\riiti\appdata\local\programs\python\python310\lib\site-packages (from nltk) (8.1.3)
# Requirement already satisfied: tqdm in c:\users\riiti\appdata\local\programs\python\python310\lib\site-packages (from nltk) (4.64.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\riiti\appdata\local\programs\python\python310\lib\site-packages (from nltk) (2022.9.13)
# Requirement already satisfied: colorama in c:\users\riiti\appdata\local\programs\python\python310\lib\site-packages (from click->nltk) (0.4.5)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.

# %%
#traing model

import nltk
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle

import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD
import random

words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open('intents.json').read()
intents = json.loads(data_file)


for intent in intents['intents']:
    for pattern in intent['patterns']:

        #tokenize each word
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        #add documents in the corpus
        documents.append((w, intent['tag']))

        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# lemmaztize and lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
# sort classes
classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
print (len(documents), "documents")
# classes = intents
print (len(classes), "classes", classes)
# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)


pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))

# create our training data
training = []
# create an empty array for our output
output_empty = [0] * len(classes)
# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
    
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    
    training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")


# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#fitting and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)

print("model created")
# Out:
# [nltk_data] Error loading punkt: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>
# [nltk_data] Error loading wordnet: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>
# [nltk_data] Error loading omw-1.4: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>
# 57 documents
# 11 classes ['adverse_drug', 'blood_pressure', 'blood_pressure_search', 'fever symptoms', 'fever_symptoms', 'goodbye', 'greeting', 'hospital_search', 'options', 'pharmacy_search', 'thanks']
# 101 unique lemmatized words ["'s", ',', 'a', 'ache', 'adverse', 'all', 'and', 'anyone', 'are', 'awesome', 'be', 'behavior', 'blood', 'by', 'bye', 'can', 'causing', 'chatting', 'check', 'chill', 'could', 'data', 'day', 'dehydration', 'detail', 'do', 'dont', 'drug', 'entry', 'fever', 'find', 'for', 'general', 'give', 'good', 'goodbye', 'have', 'headache', 'hello', 'help', 'helpful', 'helping', 'hey', 'hi', 'history', 'hola', 'hospital', 'how', 'i', 'id', 'irritability', 'is', 'later', 'list', 'load', 'locate', 'log', 'looking', 'lookup', 'management', 'me', 'module', 'muscle', 'nearby', 'next', 'nice', 'of', 'offered', 'open', 'patient', 'pharmacy', 'pressure', 'provide', 'reaction', 'related', 'result', 'search', 'searching', 'see', 'shivering', 'show', 'suitable', 'support', 'sweating', 'task', 'thank', 'thanks', 'that', 'there', 'till', 'time', 'to', 'track', 'transfer', 'up', 'want', 'weakness', 'what', 'which', 'with', 'you']
# Training data created
# C:\Users\riiti\AppData\Local\Temp\ipykernel_5512\2321393825.py:78: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   training = np.array(training)
# C:\Users\riiti\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\optimizers\optimizer_v2\gradient_descent.py:111: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# Epoch 1/200
# 12/12 [==============================] - 1s 3ms/step - loss: 2.4163 - accuracy: 0.1053
# Epoch 2/200
# 12/12 [==============================] - 0s 3ms/step - loss: 2.3534 - accuracy: 0.1754
# Epoch 3/200
# 12/12 [==============================] - 0s 3ms/step - loss: 2.3079 - accuracy: 0.1228
# Epoch 4/200
# 12/12 [==============================] - 0s 3ms/step - loss: 2.1727 - accuracy: 0.2807
# Epoch 5/200
# 12/12 [==============================] - 0s 3ms/step - loss: 2.0612 - accuracy: 0.3333
# Epoch 6/200
# 12/12 [==============================] - 0s 3ms/step - loss: 2.0173 - accuracy: 0.3509
# Epoch 7/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.7670 - accuracy: 0.5088
# Epoch 8/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.6923 - accuracy: 0.5614
# Epoch 9/200
# 12/12 [==============================] - 0s 3ms/step - loss: 1.5732 - accuracy: 0.5088
# Epoch 10/200
# 12/12 [==============================] - 0s 3ms/step - loss: 1.4949 - accuracy: 0.5088
# Epoch 11/200
# 12/12 [==============================] - 0s 4ms/step - loss: 1.2966 - accuracy: 0.6667
# Epoch 12/200
# 12/12 [==============================] - 0s 3ms/step - loss: 1.1709 - accuracy: 0.6667
# Epoch 13/200
# 12/12 [==============================] - 0s 3ms/step - loss: 1.3411 - accuracy: 0.5088
# Epoch 14/200
# 12/12 [==============================] - 0s 2ms/step - loss: 1.0216 - accuracy: 0.7193
# Epoch 15/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.9724 - accuracy: 0.7018
# Epoch 16/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.8699 - accuracy: 0.7544
# Epoch 17/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.9124 - accuracy: 0.7719
# Epoch 18/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6623 - accuracy: 0.8421
# Epoch 19/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.7484 - accuracy: 0.7368
# Epoch 20/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.8156 - accuracy: 0.7544
# Epoch 21/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6245 - accuracy: 0.8421
# Epoch 22/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6606 - accuracy: 0.8421
# Epoch 23/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5122 - accuracy: 0.8947
# Epoch 24/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4703 - accuracy: 0.8772
# Epoch 25/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3574 - accuracy: 0.9474
# Epoch 26/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4830 - accuracy: 0.8772
# Epoch 27/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4405 - accuracy: 0.8947
# Epoch 28/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3391 - accuracy: 0.8772
# Epoch 29/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5083 - accuracy: 0.8246
# Epoch 30/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4156 - accuracy: 0.8772
# Epoch 31/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2731 - accuracy: 0.9649
# Epoch 32/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2699 - accuracy: 0.9298
# Epoch 33/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2779 - accuracy: 0.9649
# Epoch 34/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3054 - accuracy: 0.9123
# Epoch 35/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1744 - accuracy: 0.9474
# Epoch 36/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3117 - accuracy: 0.8772
# Epoch 37/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3095 - accuracy: 0.9123
# Epoch 38/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2748 - accuracy: 0.9123
# Epoch 39/200
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3086 - accuracy: 0.9123
# Epoch 40/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1807 - accuracy: 0.9298
# Epoch 41/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1940 - accuracy: 0.9474
# Epoch 42/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1428 - accuracy: 0.9649
# Epoch 43/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2314 - accuracy: 0.9123
# Epoch 44/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1622 - accuracy: 0.9825
# Epoch 45/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1212 - accuracy: 0.9825
# Epoch 46/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2043 - accuracy: 0.9649
# Epoch 47/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1183 - accuracy: 0.9649
# Epoch 48/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1530 - accuracy: 0.9825
# Epoch 49/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0990 - accuracy: 0.9825
# Epoch 50/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0955 - accuracy: 0.9649
# Epoch 51/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1579 - accuracy: 0.9474
# Epoch 52/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0980 - accuracy: 1.0000
# Epoch 53/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2413 - accuracy: 0.9298
# Epoch 54/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0688 - accuracy: 1.0000
# Epoch 55/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1178 - accuracy: 0.9825
# Epoch 56/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1713 - accuracy: 0.9298
# Epoch 57/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1852 - accuracy: 0.9298
# Epoch 58/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1031 - accuracy: 0.9825
# Epoch 59/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1296 - accuracy: 0.9649
# Epoch 60/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1024 - accuracy: 0.9825
# Epoch 61/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1306 - accuracy: 0.9649
# Epoch 62/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1401 - accuracy: 0.9649
# Epoch 63/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1087 - accuracy: 0.9649
# Epoch 64/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1484 - accuracy: 0.9474
# Epoch 65/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1057 - accuracy: 0.9649
# Epoch 66/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0972 - accuracy: 0.9649
# Epoch 67/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1057 - accuracy: 0.9825
# Epoch 68/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1581 - accuracy: 0.9649
# Epoch 69/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0846 - accuracy: 1.0000
# Epoch 70/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0993 - accuracy: 0.9825
# Epoch 71/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0840 - accuracy: 0.9825
# Epoch 72/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1129 - accuracy: 0.9649
# Epoch 73/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0569 - accuracy: 1.0000
# Epoch 74/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1800 - accuracy: 0.9474
# Epoch 75/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0866 - accuracy: 0.9825
# Epoch 76/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0609 - accuracy: 0.9825
# Epoch 77/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0752 - accuracy: 0.9649
# Epoch 78/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1039 - accuracy: 0.9649
# Epoch 79/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0850 - accuracy: 0.9825
# Epoch 80/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1483 - accuracy: 0.9474
# Epoch 81/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1315 - accuracy: 0.9649
# Epoch 82/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0704 - accuracy: 0.9825
# Epoch 83/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1007 - accuracy: 0.9649
# Epoch 84/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0702 - accuracy: 0.9649
# Epoch 85/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0404 - accuracy: 0.9825
# Epoch 86/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0380 - accuracy: 0.9825
# Epoch 87/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1663 - accuracy: 0.9474
# Epoch 88/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0780 - accuracy: 0.9649
# Epoch 89/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0476 - accuracy: 1.0000
# Epoch 90/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0947 - accuracy: 0.9474
# Epoch 91/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0300 - accuracy: 1.0000
# Epoch 92/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0332 - accuracy: 1.0000
# Epoch 93/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0515 - accuracy: 0.9825
# Epoch 94/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0215 - accuracy: 1.0000
# Epoch 95/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0153 - accuracy: 1.0000
# Epoch 96/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0441 - accuracy: 1.0000
# Epoch 97/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0518 - accuracy: 0.9825
# Epoch 98/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0333 - accuracy: 1.0000
# Epoch 99/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1092 - accuracy: 0.9474
# Epoch 100/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0427 - accuracy: 1.0000
# Epoch 101/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0979 - accuracy: 0.9649
# Epoch 102/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0617 - accuracy: 0.9825
# Epoch 103/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0724 - accuracy: 0.9825
# Epoch 104/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0347 - accuracy: 1.0000
# Epoch 105/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0347 - accuracy: 1.0000
# Epoch 106/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0203 - accuracy: 1.0000
# Epoch 107/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0196 - accuracy: 1.0000
# Epoch 108/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0671 - accuracy: 1.0000
# Epoch 109/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0256 - accuracy: 1.0000
# Epoch 110/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0422 - accuracy: 1.0000
# Epoch 111/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0792 - accuracy: 0.9825
# Epoch 112/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0405 - accuracy: 1.0000
# Epoch 113/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0603 - accuracy: 0.9825
# Epoch 114/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0283 - accuracy: 1.0000
# Epoch 115/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0455 - accuracy: 1.0000
# Epoch 116/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0356 - accuracy: 1.0000
# Epoch 117/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0155 - accuracy: 1.0000
# Epoch 118/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0292 - accuracy: 0.9825
# Epoch 119/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0205 - accuracy: 1.0000
# Epoch 120/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0532 - accuracy: 0.9649
# Epoch 121/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0625 - accuracy: 0.9825
# Epoch 122/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0507 - accuracy: 0.9825
# Epoch 123/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0900 - accuracy: 0.9825
# Epoch 124/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0471 - accuracy: 0.9825
# Epoch 125/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0302 - accuracy: 0.9825
# Epoch 126/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0518 - accuracy: 0.9825
# Epoch 127/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0251 - accuracy: 1.0000
# Epoch 128/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0182 - accuracy: 1.0000
# Epoch 129/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0358 - accuracy: 1.0000
# Epoch 130/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0175 - accuracy: 1.0000
# Epoch 131/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0946 - accuracy: 0.9825
# Epoch 132/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1148 - accuracy: 0.9649
# Epoch 133/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0135 - accuracy: 1.0000
# Epoch 134/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0778 - accuracy: 0.9825
# Epoch 135/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0756 - accuracy: 0.9825
# Epoch 136/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 137/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0767 - accuracy: 0.9649
# Epoch 138/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0571 - accuracy: 0.9825
# Epoch 139/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0286 - accuracy: 1.0000
# Epoch 140/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0478 - accuracy: 1.0000
# Epoch 141/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0694 - accuracy: 0.9649
# Epoch 142/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0621 - accuracy: 0.9649
# Epoch 143/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0127 - accuracy: 1.0000
# Epoch 144/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0266 - accuracy: 1.0000
# Epoch 145/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0371 - accuracy: 1.0000
# Epoch 146/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 147/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0615 - accuracy: 0.9825
# Epoch 148/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0235 - accuracy: 1.0000
# Epoch 149/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0808 - accuracy: 0.9649
# Epoch 150/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0129 - accuracy: 1.0000
# Epoch 151/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 152/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0391 - accuracy: 0.9825
# Epoch 153/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0627 - accuracy: 1.0000
# Epoch 154/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0485 - accuracy: 0.9825
# Epoch 155/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0896 - accuracy: 0.9474
# Epoch 156/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0215 - accuracy: 1.0000
# Epoch 157/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0167 - accuracy: 1.0000
# Epoch 158/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 159/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0392 - accuracy: 0.9825
# Epoch 160/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0168 - accuracy: 1.0000
# Epoch 161/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0179 - accuracy: 1.0000
# Epoch 162/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0354 - accuracy: 1.0000
# Epoch 163/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0696 - accuracy: 0.9649
# Epoch 164/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0145 - accuracy: 1.0000
# Epoch 165/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0225 - accuracy: 1.0000
# Epoch 166/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0114 - accuracy: 1.0000
# Epoch 167/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0422 - accuracy: 1.0000
# Epoch 168/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0245 - accuracy: 1.0000
# Epoch 169/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0182 - accuracy: 1.0000
# Epoch 170/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0315 - accuracy: 1.0000
# Epoch 171/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0178 - accuracy: 1.0000
# Epoch 172/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0264 - accuracy: 1.0000
# Epoch 173/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0149 - accuracy: 1.0000
# Epoch 174/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0141 - accuracy: 1.0000
# Epoch 175/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0332 - accuracy: 1.0000
# Epoch 176/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0130 - accuracy: 1.0000
# Epoch 177/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0406 - accuracy: 0.9825
# Epoch 178/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0324 - accuracy: 0.9825
# Epoch 179/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0457 - accuracy: 0.9825
# Epoch 180/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0469 - accuracy: 0.9825
# Epoch 181/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 182/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0398 - accuracy: 1.0000
# Epoch 183/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 184/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 185/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0124 - accuracy: 1.0000
# Epoch 186/200
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0861 - accuracy: 0.9825
# Epoch 187/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0174 - accuracy: 1.0000
# Epoch 188/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0424 - accuracy: 0.9825
# Epoch 189/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0541 - accuracy: 0.9825
# Epoch 190/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0267 - accuracy: 1.0000
# Epoch 191/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0216 - accuracy: 1.0000
# Epoch 192/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 193/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0118 - accuracy: 1.0000
# Epoch 194/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0298 - accuracy: 1.0000
# Epoch 195/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0231 - accuracy: 1.0000
# Epoch 196/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0123 - accuracy: 1.0000
# Epoch 197/200
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0122 - accuracy: 1.0000
# Epoch 198/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0191 - accuracy: 1.0000
# Epoch 199/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 200/200
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0458 - accuracy: 0.9825
# model created

# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import pickle
import numpy as np

from tensorflow.keras.models import load_model
model = load_model('chatbot_model.h5')
import json
import random
intents = json.loads(open('intents.json').read())
words = pickle.load(open('words.pkl','rb'))
classes = pickle.load(open('classes.pkl','rb'))


def clean_up_sentence(sentence):
    # tokenize the pattern - split words into array
    sentence_words = nltk.word_tokenize(sentence)
    # stem each word - create short form for word
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words

# return bag of words array: 0 or 1 for each word in the bag that exists in the sentence

def bow(sentence, words, show_details=True):
    # tokenize the pattern
    sentence_words = clean_up_sentence(sentence)
    # bag of words - matrix of N words, vocabulary matrix
    bag = [0]*len(words)  
    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s: 
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % w)
    return(np.array(bag))

def predict_class(sentence, model):
    # filter out predictions below a threshold
    p = bow(sentence, words,show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD]
    # sort by strength of probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list

def getResponse(ints, intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag']== tag):
            result = random.choice(i['responses'])
            break
    return result

def chatbot_response(msg):
    ints = predict_class(msg, model)
    res = getResponse(ints, intents)
    return res


#Creating GUI with tkinter
import tkinter
from tkinter import *


def send():
    msg = EntryBox.get("1.0",'end-1c').strip()
    EntryBox.delete("0.0",END)

    if msg != '':
        ChatLog.config(state=NORMAL)
        ChatLog.insert(END, "You: " + msg + '\n\n')
        ChatLog.config(foreground="#442265", font=("Verdana", 12 ))
    
        res = chatbot_response(msg)
        ChatLog.insert(END, "Bot: " + res + '\n\n')
            
        ChatLog.config(state=DISABLED)
        ChatLog.yview(END)
 

base = Tk()
base.title("HealthMitra")
base.geometry("400x500")
base.resizable(width=FALSE, height=FALSE)

#Create Chat window
ChatLog = Text(base, bd=0, bg="white", height="8", width="50", font="Arial",)

ChatLog.config(state=DISABLED)

#Bind scrollbar to Chat window
scrollbar = Scrollbar(base, command=ChatLog.yview, cursor="heart")
ChatLog['yscrollcommand'] = scrollbar.set

#Create Button to send message
SendButton = Button(base, font=("Verdana",12,'bold'), text="Send", width="12", height=5,
                    bd=0, bg="#32de97", activebackground="#3c9d9b",fg='#ffffff',
                    command= send )

#Create the box to enter message
EntryBox = Text(base, bd=0, bg="white",width="29", height="5", font="Arial")
#EntryBox.bind("<Return>", send)


#Place all components on the screen
scrollbar.place(x=376,y=6, height=386)
ChatLog.place(x=6,y=6, height=386, width=370)
EntryBox.place(x=128, y=401, height=90, width=265)
SendButton.place(x=6, y=401, height=90)

base.mainloop()
